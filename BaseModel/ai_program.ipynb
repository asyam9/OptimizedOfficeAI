# %%
# TODO : 경로를 확인하여 주세요.
# %run ./Model_Mlp.ipynb
# Out:
# Model(object) 클래스 호출
# MlpModel(Model) 클래스 호출

# %%
# %run ./Model_Adam.ipynb
# Out:
# AdamModel 호출

# %%
# %run ./Dataset_OD.ipynb
# Out:
# Dataset 클래스 호출
# Office_Image_Dataset(Dataset) 클래스 호출
# c:\Users\a\Desktop\OptimizedProject\OptimizedOfficeAI\baseModel\Data\All_Image_mini

# %%
OD_class = Office_Image_Dataset()
# Out:
# Office_Image_Dataset.__init__ 호출
# Dataset.shuffle_data 호출

# %%
print("OD_class.ai_mode : ", OD_class.ai_mode)
print("OD_class.dataset_name : ", OD_class.dataset_name)
print(OD_class)
# Out:
# OD_class.ai_mode :  dual_select
# OD_class.dataset_name :  office_image_dataset
# Dataset : office_image_dataset | AI Mode : dual_select | Train : 100 | Test : 29 | Val : 6

# %%
adam_true_model = AdamModel(model_name='office_image_ai', dataset=OD_class, hconfigs=[5])
adam_true_model.use_adam = True
adam_true_model.exec_all(epoch_count=1, report=1, learning_rate=0.01)
# Out:
# MlpModel.init_parameters 호출
# MlpModel.alloc_layer_param 호출
# MlpModel.init_parameters 호출
# MlpModel.alloc_layer_param 호출
# MlpModel.init_parameters 호출
# MlpModel.train 호출
# [안내] office_image_ai AI Model 학습을 시작합니다.
# Dataset.shuffle_train_data 호출
# Dataset.get_train_data 호출
# MlpModel.train_step 호출
# MlpModel.forward_neuralnet 호출
# MlpModel.forward_layer 호출
# MlpModel.forward_layer 호출
# MlpModel.forward_postproc 호출
# Office_Image_Dataset.forward_postproc 호출
# Dataset.forward_postproc 호출
# Dataset.forward_postproc 호출
# MlpModel.eval_accuracy 호출
# Office_Image_Dataset.eval_accuracy 호출
# Dataset.eval_accuracy 호출
# Dataset.eval_accuracy 호출
# MlpModel.backprop_postproc 호출
# Office_Image_Dataset.backprop_postproc 호출
# Dataset.backprop_postproc 호출
# Dataset.backprop_postproc 호출
# MlpModel.backprop_neuralnet 호출
# AdamModel.backprop_layer 호출
# AdamModel.update_param 호출
# AdamModel.eval_adam_delta 호출
# AdamModel.update_param 호출
# AdamModel.eval_adam_delta 호출
# AdamModel.backprop_layer 호출
# ...

# %%
adam_true_model.visualize(5)
# Out:
# MlpModel.visualize 호출
# [안내] office_image_ai AI Model 결과를 출력합니다.
# dataset_get_validate_data() 호출
# MlpModel.get_estimate 호출
# MlpModel.forward_neuralnet 호출
# MlpModel.forward_layer 호출
# MlpModel.forward_layer 호출
# Office_Image_Dataset.get_estimate 호출
# Dataset.get_estimate 호출
# Dataset.get_estimate 호출
# Office_Image_Dataset.visualize 호출
# [도메인 추정결과]
# 추정확률분포 [50,50] => 추정 smart : 정답 webcam => X
# 추정확률분포 [50,50] => 추정 smart : 정답 webcam => X
# 추정확률분포 [50,50] => 추정 smart : 정답 webcam => X
# 추정확률분포 [50,50] => 추정 smart : 정답 webcam => X
# 추정확률분포 [50,50] => 추정 smart : 정답 webcam => X
# [상품(오브젝트) 추정결과]
# 추정확률분포 [34,34,32] => 추정 bike : 정답 bike_helmet => X
# 추정확률분포 [34,34,32] => 추정 bike : 정답 bike_helmet => X
# 추정확률분포 [34,34,32] => 추정 bike : 정답 bike_helmet => X
# 추정확률분포 [34,34,32] => 추정 bike : 정답 back_pack => X
# 추정확률분포 [34,34,32] => 추정 bike : 정답 back_pack => X
